# %%
from IPython.display import clear_output

# %%
import json
with open('redacted2.jsonl') as f:
    data1 = [json.loads(line) for line in f]
with open('bloom-redacted.jsonl') as f:
    data2 = [json.loads(line) for line in f]

# %%
counter = 0
for d1,d2 in zip(data1, data2):
    if d1==d2:
        continue
    else:
        print(d1["redacted"])
        print("----------------------------------------------------")
        print(d2["redacted"])
        a = input()
        if a == "q" or a == "Q":
            break
        clear_output()
        
print(counter/len(data1))
# Out:
# Click Here for Items Related To - Dow Jones Industrial Average
# Dow Jones Industrial Average on: [Wikipedia] [Google] [Bing] [Yahoo] [DuckDuckGo] [Baidu]
# ...
